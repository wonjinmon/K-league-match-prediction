# %%
from glob import glob

import pandas as pd

#최종 df 먼저 생성 
df = []
years = [2021,2022,2023]

for year in years:
    datas = glob(f'k_datasets/{year}/*.xlsx')
    print(datas)

    teams = [xlsx.split('_')[-2] for xlsx in datas]

    # concat 기준이 될 df 먼저 생성, 
    df_year = pd.read_excel(f'{datas[0]}', engine='openpyxl')

    # H/A 헷갈려서 기준 잡는 열 생성 / 시즌 열 생성
    df_year['기준'] = teams[0]
    df_year['시즌'] = year

    # 새로운 df 불러오고 기준 df에 concat하기
    for xlsx in datas[1:]:
        team_name = xlsx.split('_')[-2]
        df_temp = pd.read_excel(f'{xlsx}', engine="openpyxl")
        df_temp["기준"] = f'{team_name}'
        df_temp["시즌"] = year
        df_year = pd.concat([df_year, df_temp])
    print(df_year.shape)
    df.append(df_year)

df = pd.concat(df, ignore_index=True)
print(df.shape)
df.tail()
# Out:
# ['k_datasets/2021\\2021_daegu_data.xlsx', 'k_datasets/2021\\2021_gangwon_data.xlsx', 'k_datasets/2021\\2021_gwangju_data.xlsx', 'k_datasets/2021\\2021_incheon_data.xlsx', 'k_datasets/2021\\2021_jeju_data.xlsx', 'k_datasets/2021\\2021_jeonbuk_data.xlsx', 'k_datasets/2021\\2021_pohang_data.xlsx', 'k_datasets/2021\\2021_seongnam_data.xlsx', 'k_datasets/2021\\2021_seoul_data.xlsx', 'k_datasets/2021\\2021_suwonFC_data.xlsx', 'k_datasets/2021\\2021_suwon_data.xlsx', 'k_datasets/2021\\2021_ulsan_data.xlsx']
# (456, 78)
# ['k_datasets/2022\\2022_daegu_data.xlsx', 'k_datasets/2022\\2022_gangwon_data.xlsx', 'k_datasets/2022\\2022_gimcheon_data.xlsx', 'k_datasets/2022\\2022_incheon_data.xlsx', 'k_datasets/2022\\2022_jeju_data.xlsx', 'k_datasets/2022\\2022_jeonbuk_data.xlsx', 'k_datasets/2022\\2022_pohang_data.xlsx', 'k_datasets/2022\\2022_seongnam_data.xlsx', 'k_datasets/2022\\2022_seoul_data.xlsx', 'k_datasets/2022\\2022_suwonFC_data.xlsx', 'k_datasets/2022\\2022_suwon_data.xlsx', 'k_datasets/2022\\2022_ulsan_data.xlsx']
# (456, 78)
# ['k_datasets/2023\\2023_daegu_data.xlsx', 'k_datasets/2023\\2023_daejeon_data.xlsx', 'k_datasets/2023\\2023_gangwon_data.xlsx', 'k_datasets/2023\\2023_gwangju_data.xlsx', 'k_datasets/2023\\2023_incheon_data.xlsx', 'k_datasets/2023\\2023_jeju_data.xlsx', 'k_datasets/2023\\2023_jeonbuk_data.xlsx', 'k_datasets/2023\\2023_pohang_data.xlsx', 'k_datasets/2023\\2023_seoul_data.xlsx', 'k_datasets/2023\\2023_suwonFC_data.xlsx', 'k_datasets/2023\\2023_suwon_data.xlsx', 'k_datasets/2023\\2023_ulsan_data.xlsx']
# (420, 78)
# (1332, 78)
#       LABEL-1   LABEL-2 LABEL-3  LABEL-4  LABEL-5  LABEL-6  LABEL-7  LABEL-8  \
# 1327       31  수원FCvs울산    AWAY        3        3        9        8        0
# 1328       32    포항vs울산    AWAY        0        0        4        1        0
# 1329       33    울산vs인천    HOME        0        0        9        2        1
# 1330       34    광주vs울산    AWAY        0        0       17        5        6
# 1331       35    울산vs대구    HOME        2        2       12        5        2
#
#       LABEL-9  LABEL-10  ...  LABEL-69  LABEL-70  LABEL-71  LABEL-72  \
# 1327        1         6  ...        20        47        17        11
# 1328        3         2  ...        29        52        20         5
# 1329        6         5  ...        12        42        16         7
# 1330        6         6  ...        18        58        11        11
# 1331        5         5  ...        24        59        11         7
#
#       LABEL-73  LABEL-74  LABEL-75  LABEL-76     기준    시즌
# 1327        10         9         1         0  ulsan  2023
# 1328        11        11         5         0  ulsan  2023
# 1329         7         2         2         0  ulsan  2023
# 1330        16         6         1         0  ulsan  2023
# 1331         8         7         1         0  ulsan  2023
#
# [5 rows x 78 columns]

# %%
# K_Columns 에서 컬럼명 가져오기
names = pd.read_excel('k_datasets\K_columns.xlsx', engine="openpyxl")
print(names.shape)
names.head()
# Out:
# (2, 48)
#   LABEL-1 LABEL-2 LABEL-3 LABEL-4 LABEL-5 LABEL-6 LABEL-7 LABEL-8 LABEL-9  \
# 0    Rnd.      대회     H/A      득점      도움      슈팅   유효 슈팅   블락된슈팅   벗어난슈팅
# 1      시도      성공     성공%      시도      성공     성공%      시도      성공     성공%
#
#   LABEL-10  ... LABEL-39 LABEL-40 LABEL-41 LABEL-42 LABEL-43 LABEL-44  \
# 0   PA내 슈팅  ...       블락      볼미스       파울      피파울       경고       퇴장
# 1       시도  ...      성공%       시도       성공      성공%       시도       성공
#
#   LABEL-45 LABEL-46 LABEL-47 LABEL-48
# 0      NaN      NaN      NaN      NaN
# 1      성공%       시도       성공      성공%
#
# [2 rows x 48 columns]

# %%
# 필요없는 열 제거 (성공%만 가져옴)
temp = names.drop(columns=['LABEL-45','LABEL-46','LABEL-47','LABEL-48']) 

# 컬럼명 가져와서 리스트로 저장
rows = temp.iloc[0].to_list()
print(len(rows))
print(rows)
# Out:
# 44
# ['Rnd.', '대회', 'H/A', '득점', '도움', '슈팅', '유효 슈팅', '블락된슈팅', '벗어난슈팅', 'PA내 슈팅', 'PA외 슈팅', '프리킥 슈팅', '프리킥 유효슈팅', '프리킥 크로스', '오프사이드', '코너킥', '스로인', '드리블', '패스', '키패스', '전방패스', '후방패스', '횡패스', '공격진영 패스', '수비진영 패스', '중앙진영 패스', '롱패스', '중거리패스', '단거리패스', '크로스', '탈압박', '경합 지상', '경합 공중', '태클', '클리어링', '인터셉트', '차단', '획득', '블락', '볼미스', '파울', '피파울', '경고', '퇴장']

# %%
# df의 컬럼 개수를 K_columns에 맞춰 개수 맞추기
drop_columns = ['14', '15','20','21','23','24','27', '28' ,'30' ,'31' ,'33' ,'34', '36', '37', '39', '40','42', '43' ,'45',
               '46' ,'48', '49' ,'51' ,'52' ,'54', '55', '58', '59', '61', '62', '64', '65']
for idx in (drop_columns):
    df = df.drop(columns=[f'LABEL-{idx}'])

# 확인
print(df.shape)
# print(df.columns)
df.head()
# Out:
# (1332, 46)
#    LABEL-1   LABEL-2 LABEL-3  LABEL-4  LABEL-5  LABEL-6  LABEL-7  LABEL-8  \
# 0        1  대구vs수원FC    HOME        1        1       13        4        2
# 1        2    인천vs대구    AWAY        1        0       14        2        5
# 2        3    대구vs광주    HOME        1        0       17        4        6
# 3        4    대구vs제주    HOME        1        0       16        4        3
# 4        5    전북vs대구    AWAY        2        2       17        4       10
#
#    LABEL-9  LABEL-10  ...  LABEL-69  LABEL-70  LABEL-71  LABEL-72  LABEL-73  \
# 0        7         5  ...        48        87         3         9        13
# 1        7         7  ...        59       102         2        10        13
# 2        7        10  ...        42        96         2        12        18
# 3        9        10  ...        42       102         2        14        13
# 4        3        10  ...        50       102         3         5        13
#
#    LABEL-74  LABEL-75  LABEL-76     기준    시즌
# 0        14         1         0  daegu  2021
# 1        22         1         0  daegu  2021
# 2        14         2         0  daegu  2021
# 3        14         2         0  daegu  2021
# 4        15         4         1  daegu  2021
#
# [5 rows x 46 columns]

# %%
# 컬럼명 변경 ("기준"열 제외한)
for idx, column in enumerate(df.columns[:-2]):
    df = df.rename(columns={f"{column}": f"{rows[idx]}"})

# 컬럼명 변경 확인
df.head(1)
# Out:
#    Rnd.        대회   H/A  득점  도움  슈팅  유효 슈팅  블락된슈팅  벗어난슈팅  PA내 슈팅  ...  차단  획득  \
# 0     1  대구vs수원FC  HOME   1   1  13      4      2      7       5  ...  48  87
#
#    블락  볼미스  파울  피파울  경고  퇴장     기준    시즌
# 0   3    9  13   14   1   0  daegu  2021
#
# [1 rows x 46 columns]

# %%
# 대회별 득점 비교 후 경기결과 열에 저장
for i in df["대회"].value_counts().index.tolist():
    for j in range(1,39): # 총 35개 라운드 수집
        H_score = df[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "HOME")]["득점"]
        A_score = df[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "AWAY")]["득점"]
        if len(H_score) > 0:
            if H_score.iloc[0] > A_score.iloc[0]:
                df.loc[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "HOME"), "경기결과"] = 'W'
                df.loc[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "AWAY"), "경기결과"] = 'L'
            elif H_score.iloc[0] < A_score.iloc[0]:
                df.loc[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "HOME"), "경기결과"] = 'L'
                df.loc[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "AWAY"), "경기결과"] = 'W'
            else:
                df.loc[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "HOME"), "경기결과"] = 'D'
                df.loc[(df["대회"] == i) & (df["Rnd."] == j) & (df["H/A"] == "AWAY"), "경기결과"] = 'D'

# %%
# 보기좋게 라운드 순으로 정렬
df = df.sort_values('Rnd.')

# 1,2라운드 승패 확인
df.head(24)
# Out:
#       Rnd.        대회   H/A  득점  도움  슈팅  유효 슈팅  블락된슈팅  벗어난슈팅  PA내 슈팅  ...   획득  \
# 0        1  대구vs수원FC  HOME   1   1  13      4      2      7       5  ...   87
# 456      1    대구vs서울  HOME   0   0  10      1      3      6       7  ...   53
# 608      1    제주vs포항  HOME   0   0   9      1      3      5       5  ...   59
# 1192     1    서울vs인천  HOME   2   1  13      7      2      4       7  ...   41
# 912      1    포항vs대구  AWAY   2   1   9      4      3      2       6  ...   51
# 494      1    강원vs성남  HOME   2   1  11      4      1      6       7  ...   58
# 38       1    울산vs강원  AWAY   0   0   8      2      5      1       3  ...   67
# 152      1    성남vs제주  AWAY   0   0  11      2      6      3       5  ...  117
# 874      1    울산vs김천  HOME   0   0  22      3      6     13      14  ...   78
# 532      1    울산vs김천  AWAY   0   0   6      1      1      4       4  ...   48
# 1227     1  제주vs수원FC  AWAY   0   0   9      2      2      5       7  ...   55
# 114      1    포항vs인천  AWAY   1   1   4      1      1      2       0  ...   73
# 646      1  전북vs수원FC  HOME   1   1   9      3      2      4       4  ...   57
# 760      1    대구vs서울  AWAY   2   2  11      3      1      7       6  ...   57
# 836      1    인천vs수원  AWAY   0   0   7      1      3      3       4  ...   55
# 570      1    인천vs수원  HOME   1   1  17      6      4      7       8  ...   59
# 1262     1    수원vs광주  HOME   0   0  10      5      4      1       7  ...   67
# 1297     1    울산vs전북  HOME   2   0  10      4      4      2       7  ...   63
# 76       1    수원vs광주  AWAY   0   0   2      1      0      1       1  ...   77
# 798      1  전북vs수원FC  AWAY   0   0   9      1      3      5       5  ...   70
# 947      1    대전vs강원  HOME   2   1   9      4      1      4       5  ...   71
# 1157     1    포항vs대구  HOME   3   3  12      5      2      5       7  ...   52
# 190      1    전북vs서울  HOME   2   1   9      4      1      4       5  ...  108
# 1017     1    수원vs광주  AWAY   1   1  12      3      3      6       7  ...   73
#
#       블락  볼미스  파울  피파울  경고  퇴장        기준    시즌  경기결과
# 0      3    9  13   14   1   0     daegu  2021     D
# 456   23    6  17   11   4   0     daegu  2022     L
# 608   23    9  16   16   2   0      jeju  2022     L
# 1192  31    5  16   12   3   0     seoul  2023     W
# 912   19    4  16    9   3   0     daegu  2023     L
# 494   27    8  12   12   1   0   gangwon  2022     W
# 38     3    5  12   15   1   1   gangwon  2021     L
# 152    1    5  15   10   0   1      jeju  2021     D
# 874   26    7  11   13   2   0     ulsan  2022     D
# 532   35    5  13   11   2   0  gimcheon  2022     D
# 1227  19    7  11   15   3   0   suwonFC  2023     D
# 114    6    4  13   15   3   0   incheon  2021     L
# 646   27    6  22   11   4   0   jeonbuk  2022     W
# 760   24    3  11   16   2   0     seoul  2022     W
# 836   24    6   9   15   2   1     suwon  2022     L
# 570   30    7  15    9   1   0   incheon  2022     W
# 1262  16    3  13   12   2   0     suwon  2023     W
# 1297  17    5  11   16   2   0     ulsan  2023     W
# 76     4    3  14   16   3   0   gwangju  2021     L
# 798   23    4  11   22   2   0   suwonFC  2022     L
# 947   20    8  13    7   5   0   daejeon  2023     W
# 1157  19    6   9   14   1   0    pohang  2023     W
# 190    5    6  10    5   0   0   jeonbuk  2021     W
# 1017  33    8  12   13   2   0   gwangju  2023     L
#
# [24 rows x 47 columns]

# %%
# 마지막 라운드 승패 확인
df.tail(12)
# Out:
#      Rnd.        대회   H/A  득점  도움  슈팅  유효 슈팅  블락된슈팅  벗어난슈팅  PA내 슈팅  ...  획득  \
# 683    38    전북vs인천  HOME   2   0  19      5      6      8      13  ...  52
# 797    38  수원FCvs서울  AWAY   2   1   9      6      1      2       8  ...  48
# 75     38    강원vs성남  HOME   2   0  11      7      3      1       8  ...  68
# 417    38  수원FCvs수원  AWAY   0   0  14      6      4      4      12  ...  87
# 911    38    울산vs제주  HOME   1   1   9      3      2      4       6  ...  50
# 493    38    성남vs대구  AWAY   4   3   6      5      1      0       4  ...  49
# 873    38    김천vs수원  AWAY   3   2  11      7      1      3       8  ...  53
# 531    38    포항vs강원  AWAY   0   0  11      0      2      9       6  ...  53
# 835    38  수원FCvs서울  HOME   0   0  10      0      5      5       5  ...  52
# 37     38    울산vs대구  AWAY   0   0   9      4      1      4       3  ...  84
# 379    38  수원FCvs수원  HOME   2   1  12      3      4      5       5  ...  81
# 455    38    울산vs대구  HOME   2   2  19      6      9      4      10  ...  99
#
#      블락  볼미스  파울  피파울  경고  퇴장       기준    시즌  경기결과
# 683  23   11   8   10   1   0  jeonbuk  2022     W
# 797  28   10  13    8   2   0    seoul  2022     W
# 75    1    5  14   14   3   0  gangwon  2021     W
# 417   4    7   8   13   0   0    suwon  2021     L
# 911  24    1   5    6   1   0    ulsan  2022     L
# 493  31    8  11   14   0   0    daegu  2022     D
# 873  21    6   9   17   1   0    suwon  2022     W
# 531  19    5  10    9   3   0  gangwon  2022     L
# 835  19    6   9   13   0   0  suwonFC  2022     L
# 37    9   12  13   10   3   0    daegu  2021     L
# 379   4    8  12    8   2   0  suwonFC  2021     W
# 455   1    4  10   12   1   0    ulsan  2021     W
#
# [12 rows x 47 columns]

# %%
# transfer markt 데이터 불러오고 불필요 열 제거
tm_data_2021 = pd.read_excel('k_datasets/K_trsfmk_2021.xlsx', engine='openpyxl').drop(columns=['LABEL-1','LABEL-2','LABEL-4','LABEL-5'])
tm_data_2022 = pd.read_excel('k_datasets/K_trsfmk_2022.xlsx', engine='openpyxl').drop(columns=['LABEL-1','LABEL-2','LABEL-4'])
tm_data_2023 = pd.read_excel('k_datasets/K_trsfmk_2023.xlsx', engine='openpyxl').drop(columns=['LABEL-1','LABEL-2','LABEL-4'])

# 열 이름 변경
tm_data_2021 = tm_data_2021.rename(columns={'LABEL-3' : '구단', 'LABEL-6' : '소속 선수 수',
                                'LABEL-7' : '평균 나이','LABEL-8' : '용병 수',
                                'LABEL-9' : '평균 가치', 'LABEL-10' : '총 가치'})

tm_data_2022 = tm_data_2022.rename(columns={'LABEL-3' : '구단', 'LABEL-5' : '소속 선수 수',
                                'LABEL-6' : '평균 나이','LABEL-7' : '용병 수',
                                'LABEL-8' : '평균 가치', 'LABEL-9' : '총 가치'})

tm_data_2023 = tm_data_2023.rename(columns={'LABEL-3' : '구단', 'LABEL-5' : '소속 선수 수',
                                'LABEL-6' : '평균 나이','LABEL-7' : '용병 수',
                                'LABEL-8' : '평균 가치', 'LABEL-9' : '총 가치'})

# 구단 이름 수정
tm_data_2021['구단'] = ['jeonbuk', 'ulsan', 'seoul', 'suwon', 'incheon', 'suwonFC',
                           'gangwon', 'jeju', 'pohang', 'seongnam','daegu','gwangju']

tm_data_2022['구단'] = ['jeonbuk', 'seoul', 'gimcheon', 'ulsan', 'suwon', 'jeju',
                           'pohang', 'incheon', 'gangwon', 'seongnam','daegu','suwonFC']

tm_data_2023['구단'] = ['jeonbuk', 'ulsan', 'seoul', 'suwon', 'daejeon', 'gangwon',
                           'jeju', 'incheon', 'gwangju', 'pohang','daegu','suwonFC']

# %%
# df에 tm_data_2023 합치기
tm_columns = tm_data_2021.columns[1:]

# df에 열 먼저 생성
for column in tm_columns:
    df[f'{column}'] = None
df.head(1)
# Out:
#    Rnd.        대회   H/A  득점  도움  슈팅  유효 슈팅  블락된슈팅  벗어난슈팅  PA내 슈팅  ...  경고  퇴장  \
# 0     1  대구vs수원FC  HOME   1   1  13      4      2      7       5  ...   1   0
#
#       기준    시즌  경기결과  소속 선수 수  평균 나이  용병 수  평균 가치  총 가치
# 0  daegu  2021     D     None   None  None   None  None
#
# [1 rows x 52 columns]

# %%
# !TODO
# 구단/시즌 별 트랜스퍼마켓 데이터 합치기

# 2021
for column in tm_data_2021.columns[1:]:
    for i in df['기준']:
        for j in tm_data_2021['구단']:
            if i == j:
                df.loc[(df['기준'] == i) &(df['시즌'] == 2021), f'{column}'] = tm_data_2021.loc[tm_data_2021['구단'] == j , f'{column}'].values[0]

#2022
for column in tm_data_2022.columns[1:]:
    for i in df['기준']:
        for j in tm_data_2022['구단']:
            if i == j:
                df.loc[(df['기준'] == i) &(df['시즌'] == 2022), f'{column}'] = tm_data_2022.loc[tm_data_2022['구단'] == j , f'{column}'].values[0]

#2023
for column in tm_data_2023.columns[1:]:
    for i in df['기준']:
        for j in tm_data_2023['구단']:
            if i == j:
                df.loc[(df['기준'] == i) &(df['시즌'] == 2023), f'{column}'] = tm_data_2023.loc[tm_data_2023['구단'] == j , f'{column}'].values[0]

# %%
df.head(24)
# Out:
#       Rnd.        대회   H/A  득점  도움  슈팅  유효 슈팅  블락된슈팅  벗어난슈팅  PA내 슈팅  ...  경고  \
# 0        1  대구vs수원FC  HOME   1   1  13      4      2      7       5  ...   1
# 456      1    대구vs서울  HOME   0   0  10      1      3      6       7  ...   4
# 608      1    제주vs포항  HOME   0   0   9      1      3      5       5  ...   2
# 1192     1    서울vs인천  HOME   2   1  13      7      2      4       7  ...   3
# 912      1    포항vs대구  AWAY   2   1   9      4      3      2       6  ...   3
# 494      1    강원vs성남  HOME   2   1  11      4      1      6       7  ...   1
# 38       1    울산vs강원  AWAY   0   0   8      2      5      1       3  ...   1
# 152      1    성남vs제주  AWAY   0   0  11      2      6      3       5  ...   0
# 874      1    울산vs김천  HOME   0   0  22      3      6     13      14  ...   2
# 532      1    울산vs김천  AWAY   0   0   6      1      1      4       4  ...   2
# 1227     1  제주vs수원FC  AWAY   0   0   9      2      2      5       7  ...   3
# 114      1    포항vs인천  AWAY   1   1   4      1      1      2       0  ...   3
# 646      1  전북vs수원FC  HOME   1   1   9      3      2      4       4  ...   4
# 760      1    대구vs서울  AWAY   2   2  11      3      1      7       6  ...   2
# 836      1    인천vs수원  AWAY   0   0   7      1      3      3       4  ...   2
# 570      1    인천vs수원  HOME   1   1  17      6      4      7       8  ...   1
# 1262     1    수원vs광주  HOME   0   0  10      5      4      1       7  ...   2
# 1297     1    울산vs전북  HOME   2   0  10      4      4      2       7  ...   2
# 76       1    수원vs광주  AWAY   0   0   2      1      0      1       1  ...   3
# 798      1  전북vs수원FC  AWAY   0   0   9      1      3      5       5  ...   2
# 947      1    대전vs강원  HOME   2   1   9      4      1      4       5  ...   5
# 1157     1    포항vs대구  HOME   3   3  12      5      2      5       7  ...   1
# 190      1    전북vs서울  HOME   2   1   9      4      1      4       5  ...   0
# 1017     1    수원vs광주  AWAY   1   1  12      3      3      6       7  ...   2
#
#       퇴장        기준    시즌  경기결과  소속 선수 수  평균 나이  용병 수  평균 가치     총 가치
# 0      0     daegu  2021     D       42   22.9     5  €279k  €11.70m
# 456    0     daegu  2022     L       43   22.6     6  €228k   €9.83m
# 608    0      jeju  2022     L       37   24.2     2  €328k  €12.13m
# 1192   0     seoul  2023     W       42   25.4     6  €358k  €15.05m
# 912    0     daegu  2023     L       41   24.2     5  €254k  €10.40m
# 494    0   gangwon  2022     W       33   24.2     6  €326k  €10.75m
# 38     1   gangwon  2021     L       41   23.3     5  €307k  €12.58m
# 152    1      jeju  2021     D       38   24.3     3  €317k  €12.05m
# 874    0     ulsan  2022     D       34   26.3     5  €502k  €17.08m
# 532    0  gimcheon  2022     D       40   23.5     0  €439k  €17.58m
# 1227   0   suwonFC  2023     D       37   27.1     4  €277k  €10.25m
# 114    0   incheon  2021     L       42   24.8     4  €304k  €12.75m
# 646    0   jeonbuk  2022     W       52   23.4     4  €426k  €22.18m
# 760    0     seoul  2022     W       49   23.2     6  €374k  €18.35m
# 836    1     suwon  2022     L       42   24.7     5  €322k  €13.53m
# 570    0   incheon  2022     W       37   25.9     4  €300k  €11.10m
# 1262   0     suwon  2023     W       47   26.0     7  €314k  €14.78m
# 1297   0     ulsan  2023     W       30   28.8     5  €632k  €18.95m
# 76     0   gwangju  2021     L       37   25.6     4  €288k  €10.65m
# 798    0   suwonFC  2022     L       32   26.3     4  €287k   €9.18m
# 947    0   daejeon  2023     W       45   24.5     5  €285k  €12.83m
# 1157   0    pohang  2023     W       37   25.6     4  €281k  €10.40m
# 190    0   jeonbuk  2021     W       36   25.0     5  €600k  €21.60m
# 1017   0   gwangju  2023     L       33   26.3     5  €329k  €10.85m
#
# [24 rows x 52 columns]

# %%
df.tail(24)
# Out:
#      Rnd.        대회   H/A  득점  도움  슈팅  유효 슈팅  블락된슈팅  벗어난슈팅  PA내 슈팅  ...  경고  \
# 721    38    포항vs강원  HOME   1   1   8      2      1      5       5  ...   1
# 645    38    울산vs제주  AWAY   2   2  18      5      1     12      12  ...   1
# 759    38    성남vs대구  HOME   4   2  23     11      6      6      13  ...   4
# 607    38    전북vs인천  AWAY   1   1  18      3      6      9       9  ...   3
# 113    38    광주vs인천  HOME   1   1   9      3      3      3       6  ...   1
# 569    38    김천vs수원  HOME   1   0  15      3      6      6       7  ...   4
# 151    38    광주vs인천  AWAY   1   1   8      5      0      3       4  ...   0
# 189    38    전북vs제주  AWAY   0   0   8      1      2      5       5  ...   4
# 227    38    전북vs제주  HOME   2   1  12      5      3      4      10  ...   3
# 265    38    포항vs서울  HOME   1   1   7      4      3      0       3  ...   3
# 303    38    강원vs성남  AWAY   1   1   8      2      1      5       6  ...   3
# 341    38    포항vs서울  AWAY   2   2  13      4      1      8       7  ...   1
# 683    38    전북vs인천  HOME   2   0  19      5      6      8      13  ...   1
# 797    38  수원FCvs서울  AWAY   2   1   9      6      1      2       8  ...   2
# 75     38    강원vs성남  HOME   2   0  11      7      3      1       8  ...   3
# 417    38  수원FCvs수원  AWAY   0   0  14      6      4      4      12  ...   0
# 911    38    울산vs제주  HOME   1   1   9      3      2      4       6  ...   1
# 493    38    성남vs대구  AWAY   4   3   6      5      1      0       4  ...   0
# 873    38    김천vs수원  AWAY   3   2  11      7      1      3       8  ...   1
# 531    38    포항vs강원  AWAY   0   0  11      0      2      9       6  ...   3
# 835    38  수원FCvs서울  HOME   0   0  10      0      5      5       5  ...   0
# 37     38    울산vs대구  AWAY   0   0   9      4      1      4       3  ...   3
# 379    38  수원FCvs수원  HOME   2   1  12      3      4      5       5  ...   2
# 455    38    울산vs대구  HOME   2   2  19      6      9      4      10  ...   1
#
#      퇴장        기준    시즌  경기결과  소속 선수 수  평균 나이  용병 수  평균 가치     총 가치
# 721   0    pohang  2022     W       40   24.3     4  €296k  €11.85m
# 645   0      jeju  2022     W       37   24.2     2  €328k  €12.13m
# 759   0  seongnam  2022     D       40   24.8     3  €247k   €9.88m
# 607   0   incheon  2022     L       37   25.9     4  €300k  €11.10m
# 113   0   gwangju  2021     D       37   25.6     4  €288k  €10.65m
# 569   0  gimcheon  2022     L       40   23.5     0  €439k  €17.58m
# 151   0   incheon  2021     D       42   24.8     4  €304k  €12.75m
# 189   0      jeju  2021     L       38   24.3     3  €317k  €12.05m
# 227   0   jeonbuk  2021     W       36   25.0     5  €600k  €21.60m
# 265   0    pohang  2021     L       49   23.1     5  €240k  €11.78m
# 303   0  seongnam  2021     L       35   25.1     4  €336k  €11.75m
# 341   0     seoul  2021     W       40   23.0     4  €441k  €17.63m
# 683   0   jeonbuk  2022     W       52   23.4     4  €426k  €22.18m
# 797   0     seoul  2022     W       49   23.2     6  €374k  €18.35m
# 75    0   gangwon  2021     W       41   23.3     5  €307k  €12.58m
# 417   0     suwon  2021     L       40   23.9     4  €376k  €15.05m
# 911   0     ulsan  2022     L       34   26.3     5  €502k  €17.08m
# 493   0     daegu  2022     D       43   22.6     6  €228k   €9.83m
# 873   0     suwon  2022     W       42   24.7     5  €322k  €13.53m
# 531   0   gangwon  2022     L       33   24.2     6  €326k  €10.75m
# 835   0   suwonFC  2022     L       32   26.3     4  €287k   €9.18m
# 37    0     daegu  2021     L       42   22.9     5  €279k  €11.70m
# 379   0   suwonFC  2021     W       36   25.6     5  €350k  €12.60m
# 455   0     ulsan  2021     W       34   25.9     4  €598k  €20.33m
#
# [24 rows x 52 columns]
